# %% [markdown]
# # **Importing tensorflow library**

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# %% [markdown]
# # **Importing dataset and splitting into train and validation**

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    '/kaggle/input/tomatoleaf/tomato/train',
    seed=123,
    image_size=(128,128),
    batch_size=32,
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    '/kaggle/input/tomatoleaf/tomato/val',
    seed=123,
    image_size=(128,128),
    batch_size=32
)
# Out:
# Found 10000 files belonging to 10 classes.
# Found 1000 files belonging to 10 classes.

# %% [markdown]
# # **Getting details of training and validation set**

# %%
print("Train class names:", train_ds.class_names)
print("Number of training batches:", len(train_ds))
print("Number of validation batches:", len(val_ds))

for images, labels in train_ds.take(1):
    print("First train batch shape:", images.shape)
# Out:
# Train class names: ['Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']
# Number of training batches: 313
# Number of validation batches: 32
# First train batch shape: (32, 128, 128, 3)

# %% [markdown]
# # **Getting number of classes**

# %%
num_classes = len(train_ds.class_names)
print(num_classes)
# Out:
# 10

# %% [markdown]
# # **Defining data augementation layer**

# %%
data_augementation = tf.keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# %% [markdown]
# # **Defining CNN model**

# %%
model = models.Sequential([
    data_augementation,
    layers.Rescaling(1./255),
    layers.Conv2D(32,(3,3), activation='relu',input_shape=(128,128,3)),
    layers.MaxPooling2D(pool_size=(2,2)),

    layers.Conv2D(64,(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),

    layers.Conv2D(128,(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),

    layers.Flatten(),
    layers.Dense(128,activation='relu'),
    layers.Dropout(0.5),

    layers.Dense(num_classes,activation='softmax'),
])

# %% [markdown]
# # **Compiling model**

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # **Defining reducing learning rate**

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    verbose=1,
    min_lr=1e-6,
)

# %% [markdown]
# # **Defining early stopping**

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    verbose=1,
    restore_best_weights=True,
)

# %% [markdown]
# # **Saving model checkpoints**

# %%
checkpoints = tf.keras.callbacks.ModelCheckpoint(
    'best_model.h5',
    monitor='val_loss',
    verbose=1,
    save_best_only=True
)

# %% [markdown]
# # **Defining callbacks**

# %%
callbacks = [reduce_lr, early_stopping, checkpoints]

# %% [markdown]
# # **Training model**

# %%
history = model.fit(train_ds, epochs=50, validation_data=val_ds, callbacks=callbacks)
# Out:
# Epoch 1/50
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2571 - loss: 2.0481
# Epoch 1: val_loss improved from inf to 1.09523, saving model to best_model.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - accuracy: 0.2582 - loss: 2.0452 - val_accuracy: 0.6310 - val_loss: 1.0952 - learning_rate: 0.0010
# Epoch 2/50
# 310/313 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5874 - loss: 1.2036
# Epoch 2: val_loss improved from 1.09523 to 0.68255, saving model to best_model.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.5878 - loss: 1.2024 - val_accuracy: 0.7830 - val_loss: 0.6826 - learning_rate: 0.0010
# Epoch 3/50
# 310/313 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6787 - loss: 0.9284
# Epoch 3: val_loss did not improve from 0.68255
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.6789 - loss: 0.9280 - val_accuracy: 0.7460 - val_loss: 0.7643 - learning_rate: 0.0010
# Epoch 4/50
# 310/313 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7096 - loss: 0.8323
# Epoch 4: val_loss did not improve from 0.68255
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.7098 - loss: 0.8317 - val_accuracy: 0.7690 - val_loss: 0.7517 - learning_rate: 0.0010
# Epoch 5/50
# 310/313 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7477 - loss: 0.7303
# Epoch 5: val_loss improved from 0.68255 to 0.57874, saving model to best_model.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.7478 - loss: 0.7299 - val_accuracy: 0.8080 - val_loss: 0.5787 - learning_rate: 0.0010
# Epoch 6/50
# 310/313 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7847 - loss: 0.6159
# Epoch 6: val_loss did not improve from 0.57874
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.7847 - loss: 0.6158 - val_accuracy: 0.7940 - val_loss: 0.6605 - learning_rate: 0.0010
# Epoch 7/50
# 310/313 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7960 - loss: 0.5949
# Epoch 7: val_loss improved from 0.57874 to 0.47347, saving model to best_model.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7960 - loss: 0.5947 - val_accuracy: 0.8530 - val_loss: 0.4735 - learning_rate: 0.0010
# Epoch 8/50
# 310/313 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8202 - loss: 0.5323
# Epoch 8: val_loss did not improve from 0.47347
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8202 - loss: 0.5324 - val_accuracy: 0.7780 - val_loss: 0.7356 - learning_rate: 0.0010
# Epoch 9/50
# 310/313 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8041 - loss: 0.5722
# Epoch 9: val_loss did not improve from 0.47347
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.8042 - loss: 0.5718 - val_accuracy: 0.8280 - val_loss: 0.6078 - learning_rate: 0.0010
# Epoch 10/50
# 310/313 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8332 - loss: 0.4745
# Epoch 10: val_loss improved from 0.47347 to 0.42858, saving model to best_model.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8332 - loss: 0.4744 - val_accuracy: 0.8650 - val_loss: 0.4286 - learning_rate: 0.0010
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8397 - loss: 0.4534
# Epoch 11: val_loss improved from 0.42858 to 0.42044, saving model to best_model.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8397 - loss: 0.4534 - val_accuracy: 0.8680 - val_loss: 0.4204 - learning_rate: 0.0010
# Epoch 12/50
# 310/313 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8509 - loss: 0.4303
# Epoch 12: val_loss did not improve from 0.42044
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.8509 - loss: 0.4303 - val_accuracy: 0.8300 - val_loss: 0.5653 - learning_rate: 0.0010
# Epoch 13/50
# 310/313 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8366 - loss: 0.4708
# Epoch 13: val_loss improved from 0.42044 to 0.31744, saving model to best_model.h5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8368 - loss: 0.4703 - val_accuracy: 0.9010 - val_loss: 0.3174 - learning_rate: 0.0010
# Epoch 14/50
# 310/313 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8643 - loss: 0.3881
# Epoch 14: val_loss did not improve from 0.31744
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.8642 - loss: 0.3883 - val_accuracy: 0.8030 - val_loss: 0.5584 - learning_rate: 0.0010
# Epoch 15/50
# 310/313 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8545 - loss: 0.4122
# Epoch 15: val_loss did not improve from 0.31744
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.8546 - loss: 0.4117 - val_accuracy: 0.8850 - val_loss: 0.3760 - learning_rate: 0.0010
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8663 - loss: 0.3726
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 16: val_loss did not improve from 0.31744
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8663 - loss: 0.3726 - val_accuracy: 0.8630 - val_loss: 0.4105 - learning_rate: 0.0010
# Epoch 17/50
# 310/313 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8939 - loss: 0.3045
# Epoch 17: val_loss did not improve from 0.31744
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8939 - loss: 0.3042 - val_accuracy: 0.8920 - val_loss: 0.3739 - learning_rate: 5.0000e-04
# Epoch 18/50
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9057 - loss: 0.2788
# Epoch 18: val_loss did not improve from 0.31744
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9057 - loss: 0.2787 - val_accuracy: 0.8830 - val_loss: 0.4196 - learning_rate: 5.0000e-04
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 13.

# %% [markdown]
# # **Checking loss and accuracy**

# %%
val_loss, val_acc = model.evaluate(val_ds)
print(val_loss)
print(val_acc)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8861 - loss: 0.3346
# 0.31743961572647095
# 0.9010000228881836

# %% [markdown]
# # **Saving model**

# %%
model.save("final_model.h5")
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
model.save("final_model.keras")
